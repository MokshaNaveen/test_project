# %% [markdown]
# # Lab 1

# %%
import matplotlib.pyplot as plt

# %%
Num_of_hrs_spent=[10,9,2,15,10,16,11,16]
Score_in_final_exams=[95,80,10,50,45,98,38,93]
plt.title("Study Analysis")
plt.xlabel("Hrs")
plt.ylabel("Score")
plt.plot(Num_of_hrs_spent,Score_in_final_exams,marker='*',color='r',linestyle='--')
